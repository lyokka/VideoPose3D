# %%
import sys
sys.path.append("../")

# %%
from common.camera import *
from common.visualization import *
from common.utils import *
from common.generators import ChunkedGenerator, UnchunkedGenerator
from common.h36m_dataset import Human36mDataset, preprocess_Human36m
from common.visualization import *
from common.model import *
from common.xianhui_dataset import *
import matplotlib
import glob
import plotly
import json
# %matplotlib inline
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# wild data

# %%
cam_0_data_path = "../../wild_data/2019.05.30_14.03/1.json"
cam_0_img_paths = ["../../wild_data/2019.05.30_14.03/BonesInfo_Camera_1/{}.png".format(str(i+1)) for i in range(49)]
cam_0_img_cal_paths = glob.glob('../../wild_data/2019.05.30_14.03/Camera_0/*.png')
pts_3d, cam_0_pts_2d, cam_0_params, cam_0_imgs = xianhui_data_processing(cam_0_data_path, cam_0_img_paths, cam_0_img_cal_paths, cam_id = "cam_0", chess_board_shape = (7, 5))

cam_1_data_path = "../../wild_data/2019.05.30_14.03/2.json"
cam_1_img_paths = ["../../wild_data/2019.05.30_14.03/BonesInfo_Camera_2/{}.png".format(str(i+1)) for i in range(49)]
cam_1_img_cal_paths = glob.glob('../../wild_data/2019.05.30_14.03/Camera_1/*.png')
pts_3d, cam_1_pts_2d, cam_1_params, cam_1_imgs = xianhui_data_processing(cam_1_data_path, cam_1_img_paths, cam_1_img_cal_paths, cam_id = "cam_1", chess_board_shape = (7, 5))
# Out:
# calibrate camera
# load 3d and 2d skeletons
# estimate extrinsics
# calibrate camera
# load 3d and 2d skeletons
# estimate extrinsics

# %%
cameras = {}
cameras["S1"] = [cam_0_params, cam_1_params]
data = {}
data["S1"] = {}
data["S1"]["somba"] = {
    "positions" : pts_3d,
    "cameras" : cameras["S1"]
}

dataset = XianhuiDataset(cameras, data)

# %% [markdown]
# ### preprocessing 3d data

# %%
for subject in dataset.subjects():
    for action in dataset[subject].keys():
        anim = dataset[subject][action]        
        positions_3d = []
        for cam in anim['cameras']:
            nframe = anim['positions'].shape[0]
            pts_3d_homo = np.ones((nframe, 17, 4))
            pts_3d_homo[... , :3] = anim['positions']
            pts_3d_homo = pts_3d_homo.reshape(-1, 4).T

            pts_3d_cam = world2camera_cv(pts_3d_homo, cam_0_params['rvec'], cam_0_params['tvec'])[:3]
            pos_camera = pts_3d_cam.T.reshape(nframe, 17, 3)
            pos_camera[:, 1:] -= pos_camera[:, :1]

            positions_3d.append(pos_camera)
            
        anim['positions_3d'] = positions_3d

# %% [markdown]
# ### preprocessing 2d data

# %%
keypoints = {}
keypoints["S1"] = {}
keypoints["S1"]["somba"] = [cam_0_pts_2d, cam_1_pts_2d]

for subject in keypoints.keys():
    for action in keypoints[subject]:
        for cam_idx, kps in enumerate(keypoints[subject][action]):
            # Normalize camera frame
            cam = dataset.cameras()[subject][cam_idx]
            kps[..., :2] = normalize_screen_coordinates(kps[..., :2], w=cam['res_w'], h=cam['res_h'])
            keypoints[subject][action][cam_idx] = kps

# %%
subjects_test = ['S1']

# %%
cameras_valid, poses_valid, poses_valid_2d = fetch(dataset = dataset, 
                                                   keypoints = keypoints, 
                                                   subjects = subjects_test, 
                                                   stride = 1)

# %% [markdown]
# ## generate model

# %%
model_pos = TemporalModel(poses_valid_2d[0].shape[-2], 
                          poses_valid_2d[0].shape[-1], 
                          poses_valid[0].shape[-2],
                          filter_widths = [3, 3, 3, 3, 3],
                          causal =False,
                          dropout = 0.25,
                          channels = 1024,
                          dense = False)

# %%
receptive_field = model_pos.receptive_field()
print('INFO: Receptive field: {} frames'.format(receptive_field))
pad = (receptive_field - 1) // 2 # Padding on each side
# Out:
# INFO: Receptive field: 243 frames

# %% [markdown]
# load model on gpu

# %%
if torch.cuda.is_available():
    model_pos = model_pos.cuda()

# %% [markdown]
# resume from pre-trained model

# %%
checkpoint = torch.load("../../checkpoint/pretrained_h36m_cpn.bin", map_location=lambda storage, loc: storage)
print('This model was trained for {} epochs'.format(checkpoint['epoch']))
model_pos.load_state_dict(checkpoint['model_pos'])
# Out:
# This model was trained for 80 epochs
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
input_keypoints = keypoints["S1"]["somba"][1]
gt = dataset["S1"]["somba"]["positions_3d"][0].copy()

# %%
test_generator = UnchunkedGenerator(None, 
                                    None, 
                                    [input_keypoints],
                                    pad=pad, 
                                    causal_shift=0, 
                                    augment=False)

# %%
with torch.no_grad():
    model_pos.eval()
    N = 0
    for _, batch, batch_2d in test_generator.next_epoch():
        inputs_2d = torch.from_numpy(batch_2d.astype('float32'))
        if torch.cuda.is_available():
            inputs_2d = inputs_2d.cuda()

        # Positional model
        predicted_3d_pos = model_pos(inputs_2d)
        
        prediction = predicted_3d_pos.squeeze(0).cpu().numpy()

# %% [markdown]
# Ground truth

# %%
human36m_kpts_name = ['Pelvis', 'RHip', 'RKnee', 'RAnkle','LHip','LKnee',
                      'LAnkle','Spine1','Neck', 'Head','Site','LShoulder',
                      'LElbow','LWrist','RShoulder', 'RElbow','RWrist']

# %% [markdown]
# post process output

# %%
trajectory = gt[:, :1]
gt[:, 1:] += trajectory
prediction += trajectory

# %% [markdown]
# get camera

# %%
cam = dataset.cameras()["S1"][1]

# %% [markdown]
# reproject to world coordinates

# %%
nframe = 269
gt_homo = np.ones((nframe, 17, 4))
gt_homo[... , :3] = gt
gt_homo = gt_homo.reshape(-1, 4).T
gt_reproj = camera2world_cv(gt_homo, cam["rvec"], cam["tvec"])[:3].T.reshape(-1, 17, 3)

# %%
nframe = 269
pred_homo = np.ones((nframe, 17, 4))
pred_homo[... , :3] = prediction
pred_homo = pred_homo.reshape(-1, 4).T
pred_reproj = camera2world_cv(pred_homo, cam["rvec"], cam["tvec"])[:3].T.reshape(-1, 17, 3)

# %%
obj_pts = gt.reshape(-1, 3)
xmin = obj_pts[:,0].min()
ymin = obj_pts[:,1].min()
zmin = obj_pts[:,2].min()
xmax = obj_pts[:,0].max()
ymax = obj_pts[:,1].max()
zmax = obj_pts[:,2].max()

frames, layout = generate_frames_layout(gt[::10], 
                                        dataset.skeleton(), 
                                        human36m_kpts_name, 
                                        x_range = [xmin, xmax], 
                                        y_range = [ymin, ymax], 
                                        z_range = [zmin, zmax])
fig = dict(data=get_line_3d_segs(gt, 0, dataset.skeleton(), human36m_kpts_name), layout=layout, frames=frames)
plotly.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="9f84fef2-f061-4713-849b-809021e2574b" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9f84fef2-f061-4713-849b-809021e2574b")) {
#                     Plotly.newPlot(
#                         '9f84fef2-f061-4713-849b-809021e2574b',
#                         [{"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RHip"], "type": "scatter3d", "uid": "3606379f-36bd-4fdb-8ea7-01ba497dfaa1", "x": [0.01573220456618743, 0.11412534696623272], "y": [1.6753686937613403, 1.622829245025418], "z": [8.543772992987565, 8.561522074706584]}, {"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RKnee"], "type": "scatter3d", "uid": "035004c0-f349-4aa9-b31d-8782d720a521", "x": [0.1095338676701289, 0.01573220456618743], "y": [2.0111012829579, 1.6753686937613403], "z": [8.335647482574652, 8.543772992987565]}, {"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RAnkle"], "type": "scatter3d", "uid": "3072d8ef-acbf-4193-bb7c-68902587d610", "x": [0.1530098167808941, 0.1095338676701289], "y": [2.407389732110909, 2.0111012829579], "z": [8.470917550013306, 8.335647482574652]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LHip"], "type": "scatter3d", "uid": "505a7252-b017-4dcf-8682-fc1a09b34682", "x": [0.19587892193371118, 0.11412534696623272], "y": [1.7006880862685638, 1.622829245025418], "z": [8.55820732050864, 8.561522074706584]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LKnee"], "type": "scatter3d", "uid": "482894cc-4f1f-443d-ad7f-812dd3456a2f", "x": [0.2299164043241236, 0.19587892193371118], "y": [2.087907161076049, 1.7006880862685638], "z": [8.441013963532969, 8.55820732050864]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LAnkle"], "type": "scatter3d", "uid": "8c683d05-0c0e-4285-821c-ec28a0ac1240", "x": [0.09227560844512558, 0.2299164043241236], "y": [2.3930195001475183, 2.087907161076049], "z": [8.696345791628666, 8.441013963532969]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Spine1"], "type": "scatter3d", "uid": "41f9675c-0d78-438a-b64f-8c065e622a44", "x": [0.15494514374403479, 0.11412534696623272], "y": [1.4152095950441301, 1.622829245025418], "z": [8.605477140862774, 8.561522074706584]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Neck"], "type": "scatter3d", "uid": "2b408db4-5837-4929-85b4-1c132d1d9dcc", "x": [0.17902207066379516, 0.15494514374403479], "y": [1.1332062293509084, 1.4152095950441301], "z": [8.618032475345558, 8.605477140862774]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Head"], "type": "scatter3d", "uid": "335c476d-a56e-4c06-8bde-29ba448c76f1", "x": [0.17447893658209, 0.17902207066379516], "y": [1.029543419193056, 1.1332062293509084], "z": [8.588454193587143, 8.618032475345558]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Site"], "type": "scatter3d", "uid": "4cd7029b-bf9f-4d0f-ac7a-12aaaffc469e", "x": [0.17447893658209, 0.17447893658209], "y": [1.029543419193056, 1.029543419193056], "z": [8.588454193587143, 8.588454193587143]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LShoulder"], "type": "scatter3d", "uid": "8cd1ea43-2dd7-46ba-ae8b-7c87202c6fa8", "x": [0.35513216959402466, 0.17902207066379516], "y": [1.2112123278537386, 1.1332062293509084], "z": [8.55348706573523, 8.618032475345558]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LElbow"], "type": "scatter3d", "uid": "94deb581-1afe-4cec-b8d3-983f19a65ffd", "x": [0.2908167140809297, 0.35513216959402466], "y": [1.3290847119280365, 1.2112123278537386], "z": [8.31459108825134, 8.55348706573523]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LWrist"], "type": "scatter3d", "uid": "94870914-bc3f-48f5-a2b2-4ad4ce9c6889", "x": [0.058323534459864865, 0.2908167140809297], "y": [1.1801956520499484, 1.3290847119280365], "z": [8.3204925774215, 8.314 ...
#                         {"autosize": false, "height": 700, "scene": {"aspectratio": {"x": 0.5736705680382379, "y": 0.6155908048613105, "z": 1.8107386271004513}, "camera": {"eye": {"x": -1.7428, "y": 1.0707, "z": 0.71}, "up": {"x": 0, "y": 1, "z": 0}}, "xaxis": {"range": [-0.6428133077752474, 0.815074945380845]}, "yaxis": {"range": [0.8453714442025178, 2.409793001033003]}, "zaxis": {"range": [4.440135412252977, 9.041826210184551]}}, "sliders": [{"currentvalue": {"font": {"size": 12}, "prefix": "slice: ", "visible": true, "xanchor": "center"}, "len": 1.0, "steps": [{"args": [["frame1"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "1", "method": "animate"}, {"args": [["frame2"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "2", "method": "animate"}, {"args": [["frame3"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "3", "method": "animate"}, {"args": [["frame4"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "4", "method": "animate"}, {"args": [["frame5"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "5", "method": "animate"}, {"args": [["frame6"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "6", "method": "animate"}, {"args": [["frame7"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "7", "method": "animate"}, {"args": [["frame8"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "8", "method": "animate"}, {"args": [["frame9"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "9", "method": "animate"}, {"args": [["frame10"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "10", "method": "animate"}, {"args": [["frame11"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "11", "method": "animate"

# %%
obj_pts = gt_reproj.reshape(-1, 3)
xmin = obj_pts[:,0].min()
ymin = obj_pts[:,1].min()
zmin = obj_pts[:,2].min()
xmax = obj_pts[:,0].max()
ymax = obj_pts[:,1].max()
zmax = obj_pts[:,2].max()

frames, layout = generate_frames_layout(gt_reproj[::10], 
                                        dataset.skeleton(), 
                                        human36m_kpts_name, 
                                        x_range = [xmin, xmax], 
                                        y_range = [ymin, ymax], 
                                        z_range = [zmin, zmax])
fig = dict(data=get_line_3d_segs(gt_reproj, 0, dataset.skeleton(), human36m_kpts_name), layout=layout, frames=frames)
plotly.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="fe19f0eb-a205-477c-a546-13d4c093275b" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fe19f0eb-a205-477c-a546-13d4c093275b")) {
#                     Plotly.newPlot(
#                         'fe19f0eb-a205-477c-a546-13d4c093275b',
#                         [{"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RHip"], "type": "scatter3d", "uid": "35be6f86-e55e-4b57-9b16-6ea3bf56ef38", "x": [0.5282344418650791, 0.4813025748560875], "y": [-0.38296633169007244, -0.4749485448914932], "z": [1.217755114458173, 1.26350777952063]}, {"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RKnee"], "type": "scatter3d", "uid": "1824879b-7dde-47bf-ae4b-5852f35a6cce", "x": [0.2572172798257375, 0.5282344418650791], "y": [-0.24752277725732785, -0.38296633169007244], "z": [0.9475032079392891, 1.217755114458173]}, {"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RAnkle"], "type": "scatter3d", "uid": "7fb1b087-6ced-4452-a179-66725a05be51", "x": [0.24738498754715543, 0.2572172798257375], "y": [-0.296671907232815, -0.24752277725732785], "z": [0.5295075461445302, 0.9475032079392891]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LHip"], "type": "scatter3d", "uid": "b6ceebca-21ce-4ed1-9e38-78328c3eb94b", "x": [0.40750968394249654, 0.4813025748560875], "y": [-0.5167417096742124, -0.4749485448914932], "z": [1.188911704535812, 1.26350777952063]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LKnee"], "type": "scatter3d", "uid": "86f46f22-d900-4057-92e6-a405ceb0177f", "x": [0.2316313496301623, 0.40750968394249654], "y": [-0.3904517728751786, -0.5167417096742124], "z": [0.8454745073595538, 1.188911704535812]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LAnkle"], "type": "scatter3d", "uid": "1776f408-6084-4014-8a4a-32a41579149d", "x": [0.44816708881727063, 0.2316313496301623], "y": [-0.40805923866413085, -0.3904517728751786], "z": [0.48487067850336807, 0.8454745073595538]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Spine1"], "type": "scatter3d", "uid": "4c3eec01-da1d-4d58-bbdd-a7ce73ed28b3", "x": [0.5212399617982904, 0.4813025748560875], "y": [-0.5721251918319714, -0.4749485448914932], "z": [1.4523620278757123, 1.26350777952063]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Neck"], "type": "scatter3d", "uid": "bc4dad49-891b-4efc-ad91-724975005750", "x": [0.5648782561412151, 0.5212399617982904], "y": [-0.6498891962055104, -0.5721251918319714], "z": [1.7212703616751903, 1.4523620278757123]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Head"], "type": "scatter3d", "uid": "a326102c-11ed-4ada-b501-2f84c13fa169", "x": [0.5666809789358513, 0.5648782561412151], "y": [-0.6458303360625175, -0.6498891962055104], "z": [1.8290746699089189, 1.7212703616751903]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Site"], "type": "scatter3d", "uid": "15611ecf-0745-4c39-bd9a-e169e49dfc0e", "x": [0.5666809789358513, 0.5666809789358513], "y": [-0.6458303360625175, -0.6458303360625175], "z": [1.8290746699089189, 1.8290746699089189]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LShoulder"], "type": "scatter3d", "uid": "2e5690a1-e606-4bb7-a72b-309f04d6647b", "x": [0.38276477970742917, 0.5648782561412151], "y": [-0.7177506060880408, -0.6498891962055104], "z": [1.6621489696028644, 1.7212703616751903]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LElbow"], "type": "scatter3d", "uid": "e959d758-e568-4e34-b91a-a41ed6c00bd8", "x": [0.24115700678969798, 0.38276477970742917], "y": [-0.4888113806408798, -0.7177506060880408], "z": [1.610809564618656, 1.6621489696028644]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LWrist"], "type": "scatter3d", "uid": "521384dd-4072-42b5-a552-576794181454", "x": [0.43525125649279683, 0.24115700678969798], "y": [-0.354183 ...
#                         {"autosize": false, "height": 700, "scene": {"aspectratio": {"x": 1.1299730174277225, "y": 1.1085451154427868, "z": 0.761481867129491}, "camera": {"eye": {"x": -1.7428, "y": 1.0707, "z": 0.71}, "up": {"x": 0, "y": 1, "z": 0}}, "xaxis": {"range": [-2.5258973012430794, 1.090325181357647]}, "yaxis": {"range": [-1.0165410657094966, 2.5311062741950936]}, "zaxis": {"range": [0.4645333293518723, 2.901483420669058]}}, "sliders": [{"currentvalue": {"font": {"size": 12}, "prefix": "slice: ", "visible": true, "xanchor": "center"}, "len": 1.0, "steps": [{"args": [["frame1"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "1", "method": "animate"}, {"args": [["frame2"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "2", "method": "animate"}, {"args": [["frame3"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "3", "method": "animate"}, {"args": [["frame4"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "4", "method": "animate"}, {"args": [["frame5"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "5", "method": "animate"}, {"args": [["frame6"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "6", "method": "animate"}, {"args": [["frame7"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "7", "method": "animate"}, {"args": [["frame8"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "8", "method": "animate"}, {"args": [["frame9"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "9", "method": "animate"}, {"args": [["frame10"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "10", "method": "animate"}, {"args": [["frame11"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate

# %%
frames, layout = generate_frames_layout(pred_reproj[::10], 
                                        dataset.skeleton(), 
                                        human36m_kpts_name, 
                                        x_range = [xmin, xmax], 
                                        y_range = [ymin, ymax], 
                                        z_range = [zmin, zmax])
fig = dict(data=get_line_3d_segs(pred_reproj, 0, dataset.skeleton(), human36m_kpts_name), layout=layout, frames=frames)
plotly.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="629857fb-9ac9-4c66-a701-c85a0a0f39d6" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("629857fb-9ac9-4c66-a701-c85a0a0f39d6")) {
#                     Plotly.newPlot(
#                         '629857fb-9ac9-4c66-a701-c85a0a0f39d6',
#                         [{"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RHip"], "type": "scatter3d", "uid": "742338e4-bc42-4d85-b99c-7d0a668e4b9e", "x": [0.528809463611772, 0.48128567926590904], "y": [-0.4617226062874895, -0.4749319111655099], "z": [1.2846955569491518, 1.2635061992998406]}, {"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RKnee"], "type": "scatter3d", "uid": "cf3cb8bf-a1e0-4832-ac5f-a33c34ea3c7b", "x": [0.2044374466568053, 0.528809463611772], "y": [-0.11004203298181725, -0.4617226062874895], "z": [1.3322150257071033, 1.2846955569491518]}, {"line": {"color": "red", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["RAnkle"], "type": "scatter3d", "uid": "3e5f245a-e80c-493f-a430-83deb4a7be68", "x": [-0.11985622715654376, 0.2044374466568053], "y": [0.24845597590385982, -0.11004203298181725], "z": [1.3625821291663707, 1.3322150257071033]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LHip"], "type": "scatter3d", "uid": "5e2d1722-50a3-4f5d-ab57-f0b0d1c6045d", "x": [0.43381688216537917, 0.48128567926590904], "y": [-0.48819518402390205, -0.4749319111655099], "z": [1.2423204997827781, 1.2635061992998406]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LKnee"], "type": "scatter3d", "uid": "3e4a28d5-0dd6-482d-930e-dc890a8f4dcf", "x": [0.11801541502586232, 0.43381688216537917], "y": [-0.13631660688666614, -0.48819518402390205], "z": [1.2973115902985164, 1.2423204997827781]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LAnkle"], "type": "scatter3d", "uid": "a14ceeeb-bb80-4e00-93ba-516fbee7520c", "x": [-0.10701630124094219, 0.11801541502586232], "y": [0.1882114452729713, -0.13631660688666614], "z": [1.3461266338832263, 1.2973115902985164]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Spine1"], "type": "scatter3d", "uid": "1e9d0ac9-b1f4-4a5b-8ed4-5fe7bf0f3a3c", "x": [0.6140230729350735, 0.48128567926590904], "y": [-0.6451038862028806, -0.4749319111655099], "z": [1.2702162607555962, 1.2635061992998406]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Neck"], "type": "scatter3d", "uid": "405e51c3-26c7-41ba-b62b-22b57fd5deba", "x": [0.7559009241068972, 0.6140230729350735], "y": [-0.818148657823893, -0.6451038862028806], "z": [1.3282931863605878, 1.2702162607555962]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Head"], "type": "scatter3d", "uid": "276122cb-9e52-4053-81fa-a61406a65850", "x": [0.7664536698684543, 0.7559009241068972], "y": [-0.8181612454051521, -0.818148657823893], "z": [1.3329757322378768, 1.3282931863605878]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["Site"], "type": "scatter3d", "uid": "d68e2b04-b199-4e6e-9462-acfa98a7a5f2", "x": [0.8073743183114637, 0.7664536698684543], "y": [-0.8782805226554675, -0.8181612454051521], "z": [1.3596586639434722, 1.3329757322378768]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LShoulder"], "type": "scatter3d", "uid": "97dbb643-156a-4905-94a0-56ea258c87d3", "x": [0.6850756710186943, 0.7559009241068972], "y": [-0.8106083096087655, -0.818148657823893], "z": [1.3047425648085058, 1.3282931863605878]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LElbow"], "type": "scatter3d", "uid": "d866c452-2d9b-486e-8b9d-a34ad4dcacb0", "x": [0.6422197355473491, 0.6850756710186943], "y": [-0.6728367783840898, -0.8106083096087655], "z": [1.2338920359384828, 1.3047425648085058]}, {"line": {"color": "black", "width": 5}, "marker": {"color": "blue", "size": 2}, "text": ["LWrist"], "type": "scatter3d", "uid": "3f6d3991-0eb7-469d-86a6-4b9167a36b3b", "x": [0.725862952909007, 0.6422197355473491], "y": [-0 ...
#                         {"autosize": false, "height": 700, "scene": {"aspectratio": {"x": 1.1299730174277225, "y": 1.1085451154427868, "z": 0.761481867129491}, "camera": {"eye": {"x": -1.7428, "y": 1.0707, "z": 0.71}, "up": {"x": 0, "y": 1, "z": 0}}, "xaxis": {"range": [-2.5258973012430794, 1.090325181357647]}, "yaxis": {"range": [-1.0165410657094966, 2.5311062741950936]}, "zaxis": {"range": [0.4645333293518723, 2.901483420669058]}}, "sliders": [{"currentvalue": {"font": {"size": 12}, "prefix": "slice: ", "visible": true, "xanchor": "center"}, "len": 1.0, "steps": [{"args": [["frame1"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "1", "method": "animate"}, {"args": [["frame2"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "2", "method": "animate"}, {"args": [["frame3"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "3", "method": "animate"}, {"args": [["frame4"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "4", "method": "animate"}, {"args": [["frame5"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "5", "method": "animate"}, {"args": [["frame6"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "6", "method": "animate"}, {"args": [["frame7"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "7", "method": "animate"}, {"args": [["frame8"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "8", "method": "animate"}, {"args": [["frame9"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "9", "method": "animate"}, {"args": [["frame10"], {"frame": {"duration": 70, "redraw": true}, "mode": "immediate", "transition": {"duration": 0}}], "label": "10", "method": "animate"}, {"args": [["frame11"], {"frame": {"duration": 70, "redraw": true}, "mode": "immed
