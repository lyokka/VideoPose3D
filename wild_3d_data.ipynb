# %%
import matplotlib.pyplot as plt
import json
import numpy as np

import matplotlib
matplotlib.use('Agg')
from common.visualization import *
from common.utils import *
from matplotlib.collections import LineCollection

# %matplotlib inline

# %%
with open("./wild_data/1.json", 'r') as f:
    data = json.loads(f.read())
    
img = plt.imread("./wild_data/1.jpg")

# %%
data
# Out:
# {'CameraPos': {'root': {'id': 0,
#    'parent': 0.0,
#    'x': -0.10408901200201862,
#    'y': 0.06983533414971926,
#    'z': -29.997488808043098}},
#  'Program': 'SkeletonData',
#  'ScreenPos': {'chest': {'id': 1,
#    'view': 1,
#    'x': 297.0634640608316,
#    'y': 172.5898886481217},
#   'joint_left_ankle': {'id': 26,
#    'view': 1,
#    'x': 319.80474446378787,
#    'y': 396.10161154520387},
#   'joint_left_elbow': {'id': 28,
#    'view': 1,
#    'x': 338.9327869830293,
#    'y': 197.6070761193971},
#   'joint_left_hip': {'id': 24,
#    'view': 1,
#    'x': 317.10662311627146,
#    'y': 239.06029884173228},
#   'joint_left_knee': {'id': 25,
#    'view': 1,
#    'x': 318.44794932517414,
#    'y': 318.83655122242396},
#   'joint_left_shoulder': {'id': 27,
#    'view': 1,
#    'x': 330.3404765942503,
#    'y': 147.10203369900495},
#   'joint_neck': {'id': 18,
#    'view': 1,
#    'x': 295.64828156314655,
#    'y': 149.28690157980088},
#   'joint_right_ankle': {'id': 21,
#    'view': 1,
#    'x': 286.57081978008387,
#    'y': 396.9179417873851},
#   'joint_right_elbow': {'id': 23,
#    'view': 1,
#    'x': 262.77866092960045,
#    'y': 202.86325119701212},
#   'joint_right_hip': {'id': 19,
#    'view': 1,
#    'x': 284.9676418358536,
#    'y': 240.93968999629223},
#   'joint_right_knee': {'id': 20,
#    'view': 1,
#    'x': 285.779065732311,
#    'y': 320.2290090002166},
#   'joint_right_shoulder': {'id': 22,
#    'view': 1,
#    'x': 261.03871634482584,
#    'y': 151.21814344170866},
#   'joint_waist': {'id': 17,
#    'view': 1,
#    'x': 298.7610225754703,
#    'y': 201.20786259289343},
#   'left_ankle': {'id': 11,
#    'view': 2,
#    'x': 321.36021992095357,
#    'y': 401.35904187382783},
#   'left_clavicle': {'id': 16,
#    'view': 1,
#    'x': 313.70463815349297,
#    'y': 148.77666137904225},
#   'left_elbow': {'id': 13,
#    'view': 1,
#    'x': 342.459080239901,
#    'y': 218.89255087841354},
#   'left_hip': {'id': 9,
#    'view': 1,
#    'x': 317.7750576606679,
#    'y': 278.81587996719884},
#   'left_knee': {'id': 10,
#    'view': 1,
#    'x': 319.11036603929546,
#    'y': 356.5590237746885},
#   'left_shoulder': {'id': 12,
#    'view': 1,
#    'x': 334.71468446731717,
#    'y': 172.81334348517913},
#   'left_wrist': {'id': 14,
#    'view': 1,
#    'x': 346.55342003669796,
#    'y': 243.60687837506325},
#   'neck': {'id': 2,
#    'view': 1,
#    'x': 293.74798869597214,
#    'y': 121.12532516329367},
#   'right_ankle': {'id': 5,
#    'view': 2,
#    'x': 284.83921166085577,
#    'y': 401.8928753197691},
#   'right_clavicle': {'id': 15,
#    'view': 1,
#    'x': 277.73439358287186,
#    'y': 150.9130743319708},
#   'right_elbow': {'id': 7,
#    'view': 1,
#    'x': 262.0910126354604,
#    'y': 224.20655945281078},
#   'right_hip': {'id': 3,
#    'view': 1,
#    'x': 285.3721890344791,
#    'y': 280.47053450802514},
#   'right_knee': {'id': 4,
#    'view': 1,
#    'x': 286.16575361934366,
#    'y': 357.68341982599964},
#   'right_shoulder': {'id': 6,
#    'view': 1,
#    'x': 261.9247132353952,
#    'y': 177.51634011114209},
#   'right_wrist': {'id': 8,
#    'view': 1,
#    'x': 261.29240945270885,
#    'y': 248.99369853071053},
#   'root': {'id': 0,
#    'view': 1,
#    'x': 300.25998684013393,
#    'y': 226.75604284617125}},
#  'WorldPos': {'root': {'id': 0,
#    'parent': 0.0,
#    'x': 0.1025111919569035,
#    'y': 0.16983533414971927,
#    'z': 0.10408901200201862}},
#  'bbox': {'height': 280, 'width': 85, 'x': 261, 'y': 121},
#  'cam_par': {'pos': {'x': 30.1, 'y': 0.1, 'z': 1.83697019872103e-15}}}
